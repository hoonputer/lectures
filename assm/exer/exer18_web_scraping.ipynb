# %%
# pip install requests

# %%
# pip install beautifulsoup4

# %%
# pip install beautifulsoup4
"""
Exercise 1: Search '메타버스' news on Naver
"""
# HTTP Request
import requests

url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4'
res = requests.get(url)  # HTTP GET Request

html_doc = res.text      # get texts from the HTML response result

print(html_doc)
# Out:
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="메타버스 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'메타버스'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'메타버스'의 네이버 통합검색 결과입니다."> <title>메타버스 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_211202.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_211202.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = co ...
#   <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
#   <link href="https://ssl.pstatic.net/sstatic/search/sa/211129/css/powerlink.css" rel="stylesheet" type="text/css">
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css">
#   <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head nx_power"><h2>파워링크</h2>
#
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">메타버스</strong><em
#                 class="dsc_ncaution_quotation">&rsquo;</em></span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#         <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
#
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704" class="link_help">도움말</a></p>
#           <button type="button" class="bt_ad_clse">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=jYGNpBzYgldlF1cy_dmOtiJZ4-...">
#       <ul class="lst_type">
#         <li class="lst  type_more type_subtitle    type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=G2d9iRjq3j8KK25gReeBjv///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000160175006&amp;d=&#39;+urlencode(&#39;https://megastudy-computer.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMDEwMDdfMjg3/MDAxNjAyMDUxMDE1NTY3._Srrq6fbj1_rb2hul3W3ZuYfGjVaFdikbCmTPmiVGZ0g.Heu5qVAVvhWUTFDFpFbT7US8A1CQwRnGCW01S8yUS2Mg.JPEG/1802017-4b9adec5-295f-4dcf-9537-e0c160b7bffa.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=/PxZcY105a1/3yvq73MfF////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000160175006&amp;d=&#39; + urlencode(&#39;https://megastudy-computer.com/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">메가스터디 메타버스</div>
#               <div class="sub_tit">윈터시즌 최대 50% 할인!</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=/PxZcY105a1/3yvq73MfF////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000160175006&amp;d=&#39;+urlencode(&#39;https://megastudy-computer.com/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">megastudy-computer.com/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>메타버스</strong>, 영상편집, 국비교육, 자격증취득, 취업지원, 소수정예, 얼리버드 특강
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more     type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=qZ2yly4dq3wglj9d3d6PF////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000159318414&amp;d=&#39;+urlencode(&#39;https://www.globalict.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTExMTlfMTky/MDAxNjM3MzA0MjM5ODY0.di9aaAdyRJuXuKLk7jAnRI1QF8h940CJRpHWY-FMfAAg.OnkYAzFF5FxH97gaCzD_546Ueh30pnf0JfU78pajf9Eg.PNG/2387608-531a0d24-6f5f-488b-b17a-d437f16cd8c4.png?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=3kUjxN8JaBmK/xPQKKbOmf///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000159318414&amp;d=&#39; + urlencode(&#39;https://www.globalict.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">GIP 글로벌ICT포털</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=3kUjxN8JaBmK/xPQKKbOmf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000159318414&amp;d=&#39;+urlencode(&#39;https://www.globalict.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.globalict.kr/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               더욱 새로워진 든든한 수출파트너, 정보통신산업진흥원이 직접 제공하는 해외IT정보
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more  ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=6+jXBEtsCUvQGqXo5dnrY////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39;+urlencode(&#39;https://ovice.in/ko/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTA5MDhfMTYg/MDAxNjMxMTA5NTI0Mjkx.zhf7KdnCyIIEgXYDnh4635oS4k3-0vtZIcx3zAU5fbog.khZlT4ZeckowYLEQJi_xfkKxfUNPWctdDV-3Qcq9G00g.PNG/2134036-37698ec8-070d-4de6-b5aa-e940a695b282.png?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=HfnxaydxI0P82ZmTCdezzP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39; + urlencode(&#39;https://ovice.in/ko/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">메타버스 플랫폼, 오비스</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=HfnxaydxI0P82ZmTCdezzP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39;+urlencode(&#39;https://ovice.in/ko/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">ovice.in/ko/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               재택근무, 온라인 이벤트 그리고 커뮤니티 활동을 위한 새로운 커뮤니케이션 헙업툴
#
#             </p></div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=xVUMA1n29df14GtBfEfQ4P///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39;+urlencode(&#39;https://ovice.in/ko/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">제품 소개</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=LrWjeNK4aXKNYK/Lq8OEC////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39;+urlencode(&#39;https://ovice.in/ko/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">요금 안내</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=WCwqwKqOsxoXBISrPP8LK////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39;+urlencode(&#39;https://ovice.in/ko/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">데모 체험</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=Bt4Ei+frnUKU5d6bwKEBRP///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000145972545&amp;d=&#39;+urlencode(&#39;https://ovice.in/ko/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">고객 사례</a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="3">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=hHs/OuDICwdOEw9AoxNUGP///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39;+urlencode(&#39;http://www.sgaedu.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTEwMDFfMTk3/MDAxNjMzMDc1NDc2NDE5.Cc6bWkCp1UZ10LG131eqI5V6st6ekMkAUk5ZAMeVgjEg.c1S7akkecnm5rRv94Y3GZ7-7zO8x9yBS-Tlcs98kA5og.JPEG/509895-6d198581-ca4f-4fcc-a475-d8e2100d7365.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=TVCoGpVJeIX8dbC4zsIJBv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39; + urlencode(&#39;http://www.sgaedu.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">서울게임아카데미 메타버스과정</div>
#               <div class="sub_tit">방문시 온라인 강의 증정!</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=TVCoGpVJeIX8dbC4zsIJBv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39;+urlencode(&#39;http://www.sgaedu.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.sgaedu.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>메타버스</strong>과정 <strong class='hl'>메타버스</strong>과정은 역시 SGA 서울게임아카데미
#
#             </p></div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=zzNsirOFrg7n4TrrOZkL9f///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39;+urlencode(&#39;http://www.sgaedu.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">아카데미소개</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=RjXTjuqrMMQ+Aa4cXrwxwP///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39;+urlencode(&#39;http://www.sgaedu.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">국비지원</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=54F8os8gx5W+0bg871YkVv///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39;+urlencode(&#39;http://www.sgaedu.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">포트폴리오</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=NRkZmbxu7JKWMsK6f196Fv///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=4&amp;i=nad-a001-01-000000161610926&amp;d=&#39;+urlencode(&#39;http://www.sgaedu.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">상담신청</a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more     type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="4">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=3CXGO5FGGStAcWTvIX0zKf///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000008485904&amp;d=&#39;+urlencode(&#39;http://www.fov-studio.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTA1MDhfMyAg/MDAxNTU3MzEyNjg0MjE2.ERra3kIb2mMxCWLHXobHDxAJRTDhyJiDT2Go5n3E28wg.kVd8bc9D7wJThN5yChX_mdHgvwxpizk2VIvmy1JCxqAg.JPEG/1157012-bd45a867-5487-41f5-a885-36467bb2550a.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=0yY5p1UCxQ4G6zpbayHOAP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000008485904&amp;d=&#39; + urlencode(&#39;http://www.fov-studio.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">VR제작 포브스튜디오(주)</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=0yY5p1UCxQ4G6zpbayHOAP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000008485904&amp;d=&#39;+urlencode(&#39;http://www.fov-studio.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.fov-studio.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               VR 제작,리얼타임 VR 제작,가상현실,콘텐츠제작 등
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle    type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="5">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=w7vLvUgAMrsVqQk6j0U3u////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000157213199&amp;d=&#39;+urlencode(&#39;http://sffilmschool.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTA3MjNfNDUg/MDAxNTYzODQ0NTg2ODY3.kflBu__UvLGhfkrozrVZw_qIAwzmtYcjYuBvoPW4APAg.fXJsqS4xb8AM4vm-xQGBGeMZFDR2LLudA_uDMQE1ODAg.JPEG/10905-bca19038-0fd5-452d-8615-f3803808fd81.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=vIB6CboXBJ3nKALxcKd6U////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000157213199&amp;d=&#39; + urlencode(&#39;http://sffilmschool.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">SF필름스쿨 세계CG대회1위</div>
#               <div class="sub_tit">초보자를 위한 취업완성시스템</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=vIB6CboXBJ3nKALxcKd6U////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000157213199&amp;d=&#39;+urlencode(&#39;http://sffilmschool.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">sffilmschool.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               해외 실무자들이 인정한 세계 학교평가 1위의 CG&VFX전문교육기관 1:1 피드백
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="6">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=Ve3e7GIBib66C0cfaOBFZf///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000159879103&amp;d=&#39; + urlencode(&#39;https://www.dreamideasoft.net/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">주식회사 드림아이디어소프트</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=Ve3e7GIBib66C0cfaOBFZf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000159879103&amp;d=&#39;+urlencode(&#39;https://www.dreamideasoft.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.dreamideasoft.net/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               주문형 <strong class='hl'>메타버스</strong>, 빅데이터,  모바일게임 개발 서비스 기업
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst type_line       "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="7">
#           <div class="line"></div>
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=dfgAkdSJafI3WIMhCntaYP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000132168506&amp;d=&#39; + urlencode(&#39;http://www.kmong.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">메타버스 아웃소싱, 크몽</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin" tabindex="0"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=8&amp;i=nad-a001-01-000000132168506&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                   </a>
#                 </span>
#
#
#               </span>
#               <a href="https://adcr.naver.com/adcr?x=dfgAkdSJafI3WIMhCntaYP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000132168506&amp;d=&#39;+urlencode(&#39;http://www.kmong.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.kmong.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>메타버스</strong>, 합리적인 가격으로 캐릭터부터 3D소스까지! + 신규회원 10만원 혜택
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst        "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="8">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=aaBo2svykey9Tslw5a31M////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000128669539&amp;d=&#39; + urlencode(&#39;https://vps.maxst.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">맥스트 공간기반 AR 플랫폼</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=aaBo2svykey9Tslw5a31M////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000128669539&amp;d=&#39;+urlencode(&#39;https://vps.maxst.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">vps.maxst.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               맥스트는 현실과 가상이 공존하는 증강현실 공간 <strong class='hl'>메타버스</strong>를 실현합니다.
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst        "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="9">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=9fdvOATYD5mfJDL85L1V3f///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000154170193&amp;d=&#39; + urlencode(&#39;http://www.sbsart.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">SBS아카데미컴퓨터아트학원</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=9fdvOATYD5mfJDL85L1V3f///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000154170193&amp;d=&#39;+urlencode(&#39;http://www.sbsart.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.sbsart.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               국비 100%무료, 자격증단기취득, 무료인강&재수강, <strong class='hl'>메타버스</strong>, 15주년 이벤트
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#       </ul>
#       <div class="section_more">
#         <a class="go_site"
#            target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&amp;referenceId=hkasIdp0JXVssixL5Lsssssstvs-135429" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">
#           더보기<i class="icon_arrow sp_ad"></i></a>
#       </div>
#     </div>
#
#
#   </div>
#
#
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nkindic_210617.css"> <section class="sc_new sp_nkindic _au_kindic_collection _prs_kdc_gng"> <div class="api_subject_bx _svp_list"> <div class="api_title_area"> <h2 class="api_title">지식백과</h2> <div class="api_title_sub"> <div class="api_sub_link"> </div> </div> </div> <div class="nkindic_area"> <div class="nkindic_basic api_ani_send _svp_item" data-cr-area=""> <div class="nkindic_tit _svp_content"> <h3><a target="_blank" href="https://terms.naver.com/entry.naver?docId=6226822&cid=43667&categoryId=43667" class="lnk_tit" onclick="return goOtherCR(this,'a=kdc_gng.title&r=1&i=08123F9A_00986aba960d&u='+urlencode(this.href));"><strong>메타버스</strong></a><span class="sub_tit">Metaverse</span></h3> <span class="lnk_sub_tit elss"><a target="_blank" href="https://terms.naver.com/entry.naver?docId=6226822&cid=43667&categoryId=43667" onclick="return goOtherCR(this,'a=kdc_gng.title&r=1&i=08123F9A_00986aba960d&u='+urlencode(this.href));">가공, 추상을 의미하는 메타(Meta)와 현실 세계를 의미하는 유니버스(Universe)의 합성어</a></span> </div> <div class="nkindic_content _svp_content"> <a target="_blank" href="https://terms.naver.com/entry.naver?docId=6226822&cid=43667&categoryId=43667" class="thumb_area" onclick="return goOtherCR(this,'a=kdc_gng.thumb&r=1&i=08123F9A_00986aba960d&u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdthumb-phinf.pstatic.net%2F%3Fsrc%3D%2522https%253A%252F%252Fpost-phinf.pstatic.net%252FMjAyMTAzMDVfMTQy%252FMDAxNjE0OTE5ODU5ODYx.QkobC7sbU1CccPWIPQo46YKwZ7vsfsGFTo6XVtOATtIg.Lwa24b6WLfZJtIVaDinZmZ-cuWlHcH8GthJZI942KuAg.JPEG%252FIpniGs2XeqvI_maI_3TQUTPEKFPY.jpg%253Ftype%253Dm4500_4500_fst%2522%26type%3Dw540%23540x360&type=f132_90" width="132" height="90" class="api_get img" alt="메타버스" onerror="kdic_noimage(this, 'bg_nimg2');"></a> <div class="content_desc"> <div class="api_txt_lines desc" onclick="return goOtherCR(this,'a=kdc_gng.terms&r=1&i=08123F9A_00986aba960d&u='+urlencode(this.href));"> 현실세계와 같은 사회·경제·문화 활동이 이뤄지는 3차원 가상세계를 일컫는 말로, 1992년 미국 SF 작가 닐 스티븐슨의 소설 《스노 크래시》에 처음 등장한 개념이다. <strong>메타버스</strong>는 5G 상용화에 따른 정보통신기술 발달과 코로나19 팬더믹에 따른 비대면 추세 가속화로 점차 주목받고 있다. | 외국어 표기 | Metaverse(영어) | 출처: 게티이미지 코리아 <strong>메타버스</strong>는... </div> <div class="nkindic_source elss"> <span class="source_txt">시사상식사전</span> </div> </div> </div> <div class="video_common_player_wrap _svp_target"> </div> </div> <div class="nkindic_basic api_ani_send _svp_item" data-cr-area=""> <div class="nkindic_tit _svp_content"> <h3><a target="_blank" href="https://terms.naver.com/entry.naver?docId=3586975&cid=59277&categoryId=59279" class="lnk_tit" onclick="return goOtherCR(this,'a=kdc_gng.title&r=2&i=80174df1_00000000043b015bd2fd6999&u='+urlencode(this.href));"><strong>메타버스</strong></a><span class="sub_tit">Metaverse</span></h3> </div> <div class="nkindic_content _svp_content"> <a target="_blank" href="https://terms.naver.com/entry.naver?docId=3586975&cid=59277&categoryId=59279" class="thumb_area" onclick="return goOtherCR(this,'a=kdc_gng.thumb&r=2&i=80174df1_00000000043b015bd2fd6999&u='+urlencode(this.href));"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F4874_000_1%2F20170504193036812_5R8JEKTIQ.jpg%2Fka40_233_i1.jpg%3Ftype%3Dw450_fst%23450x278&type=f132_90" width="132" height="90" class="api_get img" alt="메타버스" onerror="kdic_noimage(this, 'bg_nimg2');"></a> <div class="content_desc"> <div class="api_txt_lines desc" onclick="return goOtherCR(this,'a=kdc_gng.terms&r=2&i=80174df1_00000000043b015bd2fd6999&u='+urlencode(this.href));"><strong>메타버스</strong>에는 가상세계 이용자가 만들어내는 UGC(User Generated Content)가 상품으로서, 가상통화를 매개로 유통되는 특징이 있다. 미국 IT 벤처기업인 린든랩이 만든 세컨드 라이프(Second Life)의 인기가 증가하면서 <strong>메타버스</strong>에 대한 관심이 크게 높아지고 있다. <strong>메타버스</strong> 세계는 그 동안 가상현실(Virtual Reality)이라는 말로 표현되었는데, 현재는 진보된 개념의... </div> <div class="nkindic_source elss"> <span class="source_txt">손에 잡히는 방송통신융합 시사용어</span> </div> </di ...
#
#
#
#  <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <section class="sc_new sp_nvideo _fe_video_collection _prs_vdo_lst"> <div class="api_subject_bx _svp_list"> <div class="api_title_area"> <h2 class="api_title">동영상</h2> </div> <ul class="video_default_list"> <li class="video_item _svp_item " data-cr-area="vdo_lst*G" data-cr-gdid="a00000fa_a648637626bf5b5691b9bbcb" data-cr-gparam="1:1:0:1111|a00000fa_a648637626bf5b5691b9bbcb:0|0:0:0:1:1" data-cr-rank="1" data-cr-url="https://www.youtube.com/watch?v=7SeJ6anb3TU" > <div class="video_bx  api_ani_send _svp_content " data-video-selector=".api_mov" > <div class="thumb_area"> <a href="https://www.youtube.com/watch?v=7SeJ6anb3TU" target="_blank" class="link _svp_trigger "  data-auto-play="true" data-source="youtube" data-is-visible-close-btn="true" data-api="https://s.search.naver.com/p/video/search.naver?where=inkey&amp;vid=a00000fa_a648637626bf5b5691b9bbcb:0&amp;ie=utf8&amp;rev=45" > <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fi.ytimg.com%2Fvi%2F7SeJ6anb3TU%2Fmqdefault.jpg&type=ac324_186" onError="$Element(this).className('bg_nimg2').attr({src:'...',alt:'이미지준비중'})" width="162" height="93" alt="99%가 메타버스를 오해" class="thumb  api_get api_img"> <i class="spnew api_ico_video quick">동영상 바로재생 버튼</i> <span class="time" aria-label="재생시간 00:27:00">27:00</span> </a> </div> <div class="info_area"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-cr-on="a=vdo_lst*G.kep" data-url="https://www.youtube.com/watch?v=7SeJ6anb3TU" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_report _report" onclick="tCR('a=vdo_lst*G.report&u=javascript');return false;" data-report="%5B+%7B%22schRsltCatDtlCd%22%3A+%22TSH%22%2C%22schSvcCatDtlCd%22%3A+%22VID%22%2C%22svcDtlCd%22%3A+%22YIC%22%2C%22orgncArtclId%22%3A+%22youtube+https%3A%2F%2Fwww.youtube.com%2Fchannel%2FUCKTMvIu9a4VGSrpWy-8bUrQ+https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D7SeJ6anb3TU%22%2C%22cntsUrl%22%3A+%22https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3D7SeJ6anb3TU%22%2C%22orgncSvcId%22%3A+%22VID%22%2C%22orgncSvcNm%22%3A+%22Youtube%22%2C%22reportKwdNm%22%3A+%22%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4%22%2C%22artclTitle%22%3A+%2299%25%EA%B0%80+%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4%EB%A5%BC+%EC%98%A4%ED%95%B4%ED%95%98%EA%B3%A0+%EC%9E%88%EB%8B%A4%3F+%ED%8A%B8%EC%9C%84%EC%B9%98+%EC%B0%BD%EC%97%85%EC%9E%90%EB%93%A4%EB%81%BC%EB%A6%AC%EB%8F%84+%EB%85%BC%EC%9F%81+%EC%A4%91%21+%28%EB%B2%88%EC%97%AD+%EC%98%81%EC%83%81%29%22%2C%22artclSumryCont%22%3A+%22%22%2C%22artclRgstrId%22%3A+%22UCKTMvIu9a4VGSrpWy-8bUrQ%22%2C%22cntsLstModYmdtc%22%3A+%2220211109190508%22%2C%22cntsFstRgstYmdtc%22%3A+%2220211109190508%22%2C%22thmnlImgPath%22%3A+%22https%3A%2F%2Fi.ytimg.com%2Fvi%2F7SeJ6anb3TU%2Fmqdefault.jpg%22%7D+%5D" data-toggle-class="active" data-on-text="신고된 영상입니다.">신고하기</a> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on= ...
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
#   <div class="ad_section section _bz_section bg_type_v2">
#     <div class="section_head"><h2>비즈사이트</h2>
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em>
#           <strong class="dsc_ncaution_keyword">메타버스</strong>
#           <em class="dsc_ncaution_quotation">&rsquo;</em>
#         </span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowBz(this)) goOtherCR(this, &#39;a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#         <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#           <button type="button" class="bt_ad_clse" title="안내 레이어 닫기">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space"
#          target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
#       <ul class="lst_type ">
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=QjSlvmuF9nhVJwD9ykjB/////w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000143953037&amp;d=&#39; + urlencode(&#39;http://www.saltlux.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">메타버스의 주인공, 메타휴먼</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=QjSlvmuF9nhVJwD9ykjB/////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000143953037&amp;d=&#39;+urlencode(&#39;http://www.saltlux.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.saltlux.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               상담사, 리셉션데스크, 키오스크 등 비즈니스에 최적화된 AI 가상인간!
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=GpFs4lhFpuK+islv6/3TtP///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000150671001&amp;d=&#39; + urlencode(&#39;http://www.sbscgacademy.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">SBS아카데미CG학원 본원</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=GpFs4lhFpuK+islv6/3TtP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000150671001&amp;d=&#39;+urlencode(&#39;http://www.sbscgacademy.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.sbscgacademy.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               수강료 최대 45%할인, 포트폴리오 무료 수강권 증정, 실무자1:1피드백<strong class='hl'>메타버스</strong>
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=PflINRMXkJ/YqXmqBxvscf///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000147469035&amp;d=&#39; + urlencode(&#39;http://www.metaverse4u.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">메타버스비쥬얼웍스</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=PflINRMXkJ/YqXmqBxvscf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000147469035&amp;d=&#39;+urlencode(&#39;http://www.metaverse4u.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.metaverse4u.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               <strong class='hl'>메타버스</strong> 플랫폼 전문 매니지먼트,  제페토 월드 구축, 로블록스.디토랜드 제작
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="3">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=EXBvb5xk2OpUs5wAl0O63P///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000157438879&amp;d=&#39; + urlencode(&#39;https://gitple.io&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">개발자없이 만드는 챗봇 깃플</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=EXBvb5xk2OpUs5wAl0O63P///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000157438879&amp;d=&#39;+urlencode(&#39;https://gitple.io&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">gitple.io</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               개발자 없이 누구나 쉽고 빠르게 5분안에 만드는 시나리오 챗봇, 깃플챗
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="4">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=Xv3B5EyBj6avL5q47imteP///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000160597893&amp;d=&#39; + urlencode(&#39;http://metabuzz.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">메타버즈 - METABUZZ</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=Xv3B5EyBj6avL5q47imteP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000160597893&amp;d=&#39;+urlencode(&#39;http://metabuzz.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">metabuzz.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               제페토, 로블록스, 게더타운 월드 맵 기획 / 개발 / 홍보, 3D 아이템 제작
#
#             </p></div>
#
#           </div>
#         </li>
#       </ul>
#       <div class="section_more">
#         <a class="go_site"
#            target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&amp;referenceId=hkasIdp0JXVssixL5Lsssssstvs-135429" onclick="return goOtherCR(this, &#39;a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u=&#39;+urlencode(this.href));">
#           더보기<i class="icon_arrow sp_ad"></i></a>
#       </div>
#     </div>
#
#
#   </div>
#
#   <div class="api_sc_page_wrap"> <div class="sc_page"> <a role="button" class="btn_prev" aria-disabled="true"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a href="?query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&sm=tab_pge&where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&r=1&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="true">1</a> <a href="?display=15&f=&filetype=0&page=2&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=1&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=2&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">2</a> <a href="?display=15&f=&filetype=0&page=3&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=16&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=3&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">3</a> <a href="?display=15&f=&filetype=0&page=4&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=31&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=4&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">4</a> <a href="?display=15&f=&filetype=0&page=5&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=46&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=5&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">5</a> <a href="?display=15&f=&filetype=0&page=6&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=61&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=6&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">6</a> <a href="?display=15&f=&filetype=0&page=7&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=76&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=7&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">7</a> <a href="?display=15&f=&filetype=0&page=8&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=91&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=8&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">8</a> <a href="?display=15&f=&filetype=0&page=9&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=106&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=9&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">9</a> <a href="?display=15&f=&filetype=0&page=10&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=121&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=10&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">10</a> </div> <a href="?display=15&f=&filetype=0&page=11&query=%EB%A9%94%ED%83%80%EB%B2%84%EC%8A%A4&research_url=&sm=tab_pge&start=1&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=11&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn_next" aria-disabled="false"><i class="spnew ico_page_arr">다음</i></a> </div> </div> </div><div id="sub_pack" class="sub_pack"><section class="sc_new sp_nkeyword" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a href="https://help.naver.com/support/alias/search/word/word_1.naver" class="api_link_help" onclick="return goOtherCR(this, 'a=rsk_top.guide&r=&i=&u='+urlencode(urlexpand(this.href)));" target="_blank"><i class="spnew api_ico_help">도움말</i></a></h2> <div class="api_title_sub"> <a href="https://help.naver.com/support/alias/search/word/word_2.naver" class="btn_report" onclick="return goOtherCR(this, 'a=rsk_top.report&r=&i=&u= ...

# %%
# Extract news information

news = soup.find_all("a", {"class":"news_tit"})
print(news)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a7d6077f36a8> in <module>
#       1 # Extract news information
#       2
# ----> 3 news = soup.find_all("a", {"class":"news_tit"})
#       4 print(news)
#
# NameError: name 'soup' is not defined

# %%
# First news
news[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7e1aa5e93bd1> in <module>
#       1 # First news
# ----> 2 news[0]
#
# NameError: name 'news' is not defined

# %%
# Get a url of the first news
news[0].get('href')

# %%
# Get a title
news[0].get('title')

# %%
len(news)

# %%
for i in range(len(news)):
    print(news[i].get('title'))

# %%
"""
Exercise 2: Investing.com
"""
import requests
url = 'https://www.investing.com/equities/tesla-motors'

res = requests.get(url)
html_doc = res.text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())  # structuring the tags

# %%
keys = soup.find_all('dt')
print(keys)

# %%
vals = soup.find_all('span', {'class': 'key-info_dd-numeric__2cYjc'})
print(vals)

# %%
for i in range(len(vals)):
    print(keys[i].get_text(), '=', vals[i].get_text())
